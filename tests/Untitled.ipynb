# %%
from farabio.data.biodatasets import RANZCRDataset
from torch.utils.data import DataLoader

# %%
root = "/home/data/02_SSD4TB/suzy/datasets/public"
train_dataset = RANZCRDataset(
    root=root, train=True, transform=None, download=False)

# %%
train_dataset.visualize_dataset()

# %%
#train_dataset.file_list[0][-1]
# Out:
# 2

# %%
# random_idx = np.random.randint(1, len(train_list), size=16)
# fig, axes = plt.subplots(6,6, figsize=(13,13))

# for idx, ax in enumerate(axes.ravel()):
#     img = Image.open(train_list[idx][0])
#     ax.set_title(train_list[idx][1])
#     ax.imshow(img)

# def visualize_dataset():
#     """
#     Function to visualize images and masks
#     """
    
    
#     root = "/home/data/02_SSD4TB/suzy/datasets/public"

#     train_dataset = RANZCRDataset(
#         root=root, train=True, transform=None, download=False)

#     batch_size = 12
#     train_loader = DataLoader(dataset = train_dataset, batch_size = batch_size, shuffle = True)
#     inputs, classes = next(iter(train_loader))
#     class_names = train_dataset.classes

#     #inputs, classes = next(iter(train_loader))
#     out = torchvision.utils.make_grid(inputs)
#     self.imshow(out, title=[class_names[x] for x in classes])

# visualize_dataset()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-e54f0ae96cae> in <module>
#      17     self.imshow(out, title=[class_names[x] for x in classes])
#      18
# ---> 19 visualize_dataset()
#
# <ipython-input-9-e54f0ae96cae> in visualize_dataset()
#      11     train_loader = DataLoader(dataset = train_dataset, batch_size = batch_size, shuffle = True)
#      12     inputs, classes = next(iter(train_loader))
# ---> 13     class_names = train_dataset.classes
#      14
#      15     #inputs, classes = next(iter(train_loader))
#
# AttributeError: 'RANZCRDataset' object has no attribute 'classes'
